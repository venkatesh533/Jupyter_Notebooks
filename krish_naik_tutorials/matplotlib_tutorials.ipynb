# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.arange(0,10)
y = np.arange(11,21)
a = np.arange(40,50)
b = np.arange(50,60)

# %%
#scatter plot
plt.scatter(x,y,c='g')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Graph in 2D')
plt.savefig('Test.png')
plt.show()

# %%
#plot
y = x*x
plt.plot(x,y)

# %%
plt.plot(x,y,'ro--')

# %%
np.pi
# Out:
# 3.141592653589793
